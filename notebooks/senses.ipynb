# %%
import numpy as np

# %%
def radial():
    circle_full = 2*np.pi
    circle_sections = 360
    for x in range(circle_sections):
        print(np.cos(x))
        print(np.sin(x))

# %%
radial()
# Out:
# 1.0
# 0.0
# 0.5403023058681398
# 0.8414709848078965
# -0.4161468365471424
# 0.9092974268256817
# -0.9899924966004454
# 0.1411200080598672
# -0.6536436208636119
# -0.7568024953079282
# 0.28366218546322625
# -0.9589242746631385
# 0.960170286650366
# -0.27941549819892586
# 0.7539022543433046
# 0.6569865987187891
# -0.14550003380861354
# 0.9893582466233818
# -0.9111302618846769
# 0.4121184852417566
# -0.8390715290764524
# -0.5440211108893698
# 0.004425697988050785
# -0.9999902065507035
# 0.8438539587324921
# -0.5365729180004349
# 0.9074467814501962
# 0.4201670368266409
# 0.1367372182078336
# 0.9906073556948704
# -0.7596879128588213
# 0.6502878401571168
# -0.9576594803233847
# -0.2879033166650653
# -0.27516333805159693
# -0.9613974918795568
# 0.6603167082440802
# -0.7509872467716762
# 0.9887046181866692
# 0.14987720966295234
# 0.40808206181339196
# 0.9129452507276277
# -0.5477292602242684
# 0.8366556385360561
# -0.9999608263946371
# -0.008851309290403876
# -0.5328330203333975
# ...
